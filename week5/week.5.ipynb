# %%
def scoreChallenge():
    '''score validation challenge'''
scores = [] 
while True:
    try:
        score = int(input('Enter a test score'))
        scores.append(score)
    except ValueError:
        print('Score needs to be a number')
# Out:
# Failed to connect to remote Jupyter Server.
#
# Check that the Jupyter Server URL can be reached from a browser.
#
# https://jupyter-server-4j94694gpgx5cqxvq-8888.app.github.dev/. Click <a href='https://aka.ms/vscjremoteweb'>here</a> for more information.

# %%
scoreChallenge()
# Out:
# Failed to connect to remote Jupyter Server.
#
# Check that the Jupyter Server URL can be reached from a browser.
#
# https://jupyter-server-4j94694gpgx5cqxvq-8888.app.github.dev/. Click <a href='https://aka.ms/vscjremoteweb'>here</a> for more information.
